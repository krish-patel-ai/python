# %% [markdown]
# # AI Engineer Python variables and datatypes

# %%
epochs = 100
learning_rate = 0.0001
model_name = "logistic regression"
is_training = True
result = None

print(epochs, learning_rate, model_name, is_training, result)
# Out:
# 100 0.0001 logistic regression True None

# %%
print(type(epochs))
print(type(learning_rate))
print(type(model_name))
print(type(is_training))
print(type(result))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'NoneType'>

# %%
parameters = 7000000000
print(f"model has {parameters/1000000000:.1f}B parameters")
# Out:
# model has 7.0B parameters

# %%
a = "hello"
b = a
a = "world"
print(b)   # prints hello because b is pointing towards a and new a is just creating other space in memory for that word
# Out:
# hello

# %%
print(0.1 + 0.2)          # shows the problem
print(round(0.1 + 0.2, 2)) # fix with round()
# Out:
# 0.30000000000000004
# 0.3
